# %% [markdown]
# Analyzer of PAS data

# %%
# data loader

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ---------- GLOBAL STYLE ----------
# Set Times New Roman as the default font
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['mathtext.fontset'] = 'cm'  # Computer Modern for math symbols
plt.rcParams['font.size'] = 12  # Base font size
plt.rcParams['axes.labelsize'] = 14  # Font size for axis labels
plt.rcParams['axes.titlesize'] = 14  # Font size for titles
plt.rcParams['xtick.labelsize'] = 12  # Font size for tick labels
plt.rcParams['ytick.labelsize'] = 12  # Font size for tick labels
plt.rcParams['legend.fontsize'] = 12  # Font size for legends
# Set default line width for all plots (change this value to adjust thickness)
plt.rcParams['lines.linewidth'] = 0.75

# %%
import pandas as pd
from pathlib import Path

# 1. Define your path
path_string = r"C:\Users\jeanv\OneDrive - Delft University of Technology\Uitwisseling - TUDelft\Courses\MEP\Experiments\PALS\PAS_060326_jvbfm"

# 2. CONVERT it to a Path object (This is the crucial step!)
folder_path = Path(path_string)

# 2. Setup a dictionary to hold the results
all_data = {}

# 3. Loop through every .txt file in the folder
for file in folder_path.glob("*.txt"):
    # Get the filename without the '.txt' extension to use as a key
    sample_name = file.stem 
    
    # Read the file
    df = pd.read_csv(
        file, 
        sep='\t', 
        skiprows=1, 
        header=None, 
        names=['Energy', 'S', 'S_error', 'W', 'W_error', '3g2g', '3g2g_error']
    )
    
    # Store the entire DataFrame in our dictionary
    all_data[sample_name] = df
    
    print(f"Loaded: {sample_name}")

# --- HOW TO ACCESS YOUR DATA ---
# Example: Get the 'S' column for a specific file
# If your file was "Jean_Victor.txt", the key is "Jean_Victor"
specific_s_data = all_data['Jean Victor - S316 - as-received polished']['W']
print(specific_s_data.head())

# You can even do math instantly:
# df['Time_ns'] = df['Channel'] * 0.0125  # Example conversion
# Out:
# Loaded: Empty 2
# Loaded: Jean Victor - S316 - as-received polished double-sided - 1
# Loaded: Jean Victor - S316 - as-received polished
# Loaded: Jean Victor - S316 steel non-ann + polished + washed
# Loaded: Jean Victor - S316-3AA - 1
# Loaded: Jean Victor - S316-3AA - 2
# Loaded: Jean Victor - S316-3VA - 1
# Loaded: Jean Victor - S316-4VA - 1
# Loaded: Jean Victor - S316-annealed 650C 10h - 1
# Loaded: Jean Victor - S316-corroded-24h - 1
# Loaded: Jean Victor - S316-corroded-24h - 2
# Loaded: Jean Victor - S316-irrad-1dpa - 2
# Loaded: Jean Victor - S316-irrad-1dpa - 3
# Loaded: Jean Victor - S316-irrad-1dpa - pos1 - 1
# Loaded: Jean Victor - S316-irrad-1dpa - pos2 - 1
# Loaded: Jean Victor - S316-irrad-1dpa-corroded-24h - 1
# Loaded: Jean Victor - S316-irrad-4dpa-1
# Loaded: Jean Victor - S316-irrad-4dpa-backside-1
# Loaded: Jean Victor - S316-irrad-4dpa-backside-scratch-1
# Loaded: VEPFIT-Results-04-2026
# 0    0.01531
# 1    0.01813
# 2    0.02060
# 3    0.02158
# 4    0.02306
# ...

# %%
energy_316empty = all_data['Empty 2']['Energy']
s_316empty = all_data['Empty 2']['S']
s_error_316empty = all_data['Empty 2']['S_error']
w_316empty = all_data['Empty 2']['W']
w_error_316empty = all_data['Empty 2']['W_error']



# Polished Steels

energy_316NA_1 = all_data['Jean Victor - S316 - as-received polished']['Energy']
s_316NA_1 = all_data['Jean Victor - S316 - as-received polished']['S']
s_error_316NA_1 = all_data['Jean Victor - S316 - as-received polished']['S_error']
w_316NA_1 = all_data['Jean Victor - S316 - as-received polished']['W']
w_error_316NA_1 = all_data['Jean Victor - S316 - as-received polished']['W_error']

energy_316NA_2 = all_data['Jean Victor - S316 steel non-ann + polished + washed']['Energy']
s_316NA_2 = all_data['Jean Victor - S316 steel non-ann + polished + washed']['S']
s_error_316NA_2 = all_data['Jean Victor - S316 steel non-ann + polished + washed']['S_error']
w_316NA_2 = all_data['Jean Victor - S316 steel non-ann + polished + washed']['W']
w_error_316NA_2 = all_data['Jean Victor - S316 steel non-ann + polished + washed']['W_error']

energy_316NA_3 = all_data['Jean Victor - S316 - as-received polished double-sided - 1']['Energy']
s_316NA_3 = all_data['Jean Victor - S316 - as-received polished double-sided - 1']['S']
s_error_316NA_3 = all_data['Jean Victor - S316 - as-received polished double-sided - 1']['S_error']
w_316NA_3 = all_data['Jean Victor - S316 - as-received polished double-sided - 1']['W']
w_error_316NA_3 = all_data['Jean Victor - S316 - as-received polished double-sided - 1']['W_error']


# Annealed Steels
energy_316AA_1 = all_data['Jean Victor - S316-annealed 650C 10h - 1']['Energy']
s_316AA_1 = all_data['Jean Victor - S316-annealed 650C 10h - 1']['S']
s_error_316AA_1 = all_data['Jean Victor - S316-annealed 650C 10h - 1']['S_error']
w_316AA_1 = all_data['Jean Victor - S316-annealed 650C 10h - 1']['W']
w_error_316AA_1 = all_data['Jean Victor - S316-annealed 650C 10h - 1']['W_error']

energy_316AA_2 = all_data['Jean Victor - S316-3AA - 1']['Energy']
s_316AA_2 = all_data['Jean Victor - S316-3AA - 1']['S']
s_error_316AA_2 = all_data['Jean Victor - S316-3AA - 1']['S_error']
w_316AA_2 = all_data['Jean Victor - S316-3AA - 1']['W']
w_error_316AA_2 = all_data['Jean Victor - S316-3AA - 1']['W_error']

energy_316AA_3 = all_data['Jean Victor - S316-3AA - 2']['Energy']
s_316AA_3 = all_data['Jean Victor - S316-3AA - 2']['S']
s_error_316AA_3 = all_data['Jean Victor - S316-3AA - 2']['S_error']
w_316AA_3 = all_data['Jean Victor - S316-3AA - 2']['W']
w_error_316AA_3 = all_data['Jean Victor - S316-3AA - 2']['W_error']

energy_316VA_1 = all_data['Jean Victor - S316-3VA - 1']['Energy']
s_316VA_1 = all_data['Jean Victor - S316-3VA - 1']['S']
s_error_316VA_1 = all_data['Jean Victor - S316-3VA - 1']['S_error']
w_316VA_1 = all_data['Jean Victor - S316-3VA - 1']['W']
w_error_316VA_1 = all_data['Jean Victor - S316-3VA - 1']['W_error']

energy_316VA_2 = all_data['Jean Victor - S316-4VA - 1']['Energy']
s_316VA_2 = all_data['Jean Victor - S316-4VA - 1']['S']
s_error_316VA_2 = all_data['Jean Victor - S316-4VA - 1']['S_error']
w_316VA_2 = all_data['Jean Victor - S316-4VA - 1']['W']
w_error_316VA_2 = all_data['Jean Victor - S316-4VA - 1']['W_error']

# Backside Annealed
energy_316_4dpa_backside_1 = all_data['Jean Victor - S316-irrad-4dpa-backside-1']['Energy']
s_316_4dpa_backside_1 = all_data['Jean Victor - S316-irrad-4dpa-backside-1']['S']
s_error_316_4dpa_backside_1 = all_data['Jean Victor - S316-irrad-4dpa-backside-1']['S_error']
w_316_4dpa_backside_1 = all_data['Jean Victor - S316-irrad-4dpa-backside-1']['W']
w_error_316_4dpa_backside_1 = all_data['Jean Victor - S316-irrad-4dpa-backside-1']['W_error']

energy_316_4dpa_backside_2 = all_data['Jean Victor - S316-irrad-4dpa-backside-scratch-1']['Energy']
s_316_4dpa_backside_2 = all_data['Jean Victor - S316-irrad-4dpa-backside-scratch-1']['S']
s_error_316_4dpa_backside_2 = all_data['Jean Victor - S316-irrad-4dpa-backside-scratch-1']['S_error']
w_316_4dpa_backside_2 = all_data['Jean Victor - S316-irrad-4dpa-backside-scratch-1']['W']
w_error_316_4dpa_backside_2 = all_data['Jean Victor - S316-irrad-4dpa-backside-scratch-1']['W_error']


# Helium Implanted Steels
energy_316HI_1dpa = all_data['Jean Victor - S316-irrad-1dpa - 2']['Energy']
s_316HI_1dpa = all_data['Jean Victor - S316-irrad-1dpa - 2']['S']
s_error_316HI_1dpa = all_data['Jean Victor - S316-irrad-1dpa - 2']['S_error']
w_316HI_1dpa = all_data['Jean Victor - S316-irrad-1dpa - 2']['W']
w_error_316HI_1dpa = all_data['Jean Victor - S316-irrad-1dpa - 2']['W_error']

energy_316HI_1dpa_2 = all_data['Jean Victor - S316-irrad-1dpa - 3']['Energy']
s_316HI_1dpa_2 = all_data['Jean Victor - S316-irrad-1dpa - 3']['S']
s_error_316HI_1dpa_2 = all_data['Jean Victor - S316-irrad-1dpa - 3']['S_error']
w_316HI_1dpa_2 = all_data['Jean Victor - S316-irrad-1dpa - 3']['W']
w_error_316HI_1dpa_2 = all_data['Jean Victor - S316-irrad-1dpa - 3']['W_error']

energy_316HI_1dpa_pos1 = all_data['Jean Victor - S316-irrad-1dpa - pos1 - 1']['Energy']
s_316HI_1dpa_pos1 = all_data['Jean Victor - S316-irrad-1dpa - pos1 - 1']['S']
s_error_316HI_1dpa_pos1 = all_data['Jean Victor - S316-irrad-1dpa - pos1 - 1']['S_error']
w_316HI_1dpa_pos1 = all_data['Jean Victor - S316-irrad-1dpa - pos1 - 1']['W']
w_error_316HI_1dpa_pos1 = all_data['Jean Victor - S316-irrad-1dpa - pos1 - 1']['W_error']

energy_316HI_1dpa_pos2 = all_data['Jean Victor - S316-irrad-1dpa - pos2 - 1']['Energy']
s_316HI_1dpa_pos2 = all_data['Jean Victor - S316-irrad-1dpa - pos2 - 1']['S']
s_error_316HI_1dpa_pos2 = all_data['Jean Victor - S316-irrad-1dpa - pos2 - 1']['S_error']
w_316HI_1dpa_pos2 = all_data['Jean Victor - S316-irrad-1dpa - pos2 - 1']['W']
w_error_316HI_1dpa_pos2 = all_data['Jean Victor - S316-irrad-1dpa - pos2 - 1']['W_error']

energy_316HI_4dpa = all_data['Jean Victor - S316-irrad-4dpa-1']['Energy']
s_316HI_4dpa = all_data['Jean Victor - S316-irrad-4dpa-1']['S']
s_error_316HI_4dpa = all_data['Jean Victor - S316-irrad-4dpa-1']['S_error']
w_316HI_4dpa = all_data['Jean Victor - S316-irrad-4dpa-1']['W']
w_error_316HI_4dpa = all_data['Jean Victor - S316-irrad-4dpa-1']['W_error']


# Corroded samples
energy_316corr_1 = all_data['Jean Victor - S316-corroded-24h - 1']['Energy']
s_316corr_1 = all_data['Jean Victor - S316-corroded-24h - 1']['S']
s_error_316corr_1 = all_data['Jean Victor - S316-corroded-24h - 1']['S_error']
w_316corr_1 = all_data['Jean Victor - S316-corroded-24h - 1']['W']
w_error_316corr_1 = all_data['Jean Victor - S316-corroded-24h - 1']['W_error']

energy_316corr_2 = all_data['Jean Victor - S316-corroded-24h - 2']['Energy']
s_316corr_2 = all_data['Jean Victor - S316-corroded-24h - 2']['S']
s_error_316corr_2 = all_data['Jean Victor - S316-corroded-24h - 2']['S_error']
w_316corr_2 = all_data['Jean Victor - S316-corroded-24h - 2']['W']
w_error_316corr_2 = all_data['Jean Victor - S316-corroded-24h - 2']['W_error']

# Irradiated and Corroded samples
energy_316corr_1dpa = all_data['Jean Victor - S316-irrad-1dpa-corroded-24h - 1']['Energy']
s_316corr_1dpa = all_data['Jean Victor - S316-irrad-1dpa-corroded-24h - 1']['S']
s_error_316corr_1dpa = all_data['Jean Victor - S316-irrad-1dpa-corroded-24h - 1']['S_error']
w_316corr_1dpa = all_data['Jean Victor - S316-irrad-1dpa-corroded-24h - 1']['W']
w_error_316corr_1dpa = all_data['Jean Victor - S316-irrad-1dpa-corroded-24h - 1']['W_error']

# %% [markdown]
# # VEPFIT Data acquisition

# %%
import numpy as np
import os

# ---> PASTE YOUR FOLDER PATH HERE <---
# Keep the 'r' before the quotes if you are on Windows!
data_folder = r"C:\Users\jeanv\OneDrive - Delft University of Technology\Uitwisseling - TUDelft\Courses\MEP\Experiments\PALS\PAS_060326_jvbfm"


file_mapping = {
    "VEPFIT - S316L - 3AA - 1.plo": 'AA 10 h, 2', 
    "VEPFIT - S316L - 3AA - 2.plo": 'AA 10 h, 3', 
    "VEPFIT - S316L - 3VA - 1.plo": 'VA 10 h', 
    "VEPFIT - S316L - 4VA - 1.plo": 'VA 2.5 h', 
    "VEPFIT - S316L - annealed 650C 10h - 1.plo": 'AA 10 h, 1',
    "VEPFIT-S316L - as-received polished - 1.plo": 'P-1', 
    "VEPFIT - S316L - as-received polished and washed - 1.plo": 'P-2',
    "VEPFIT - S316 - irrad - 1dpa - 2.plo": '1dpa, 2', 
    "VEPFIT - S316-irrad-1dpa - pos1 - 1.plo": 'Pos1 1dpa', 
    "VEPFIT - S316-irrad-1dpa - pos2 - 1.plo": 'Pos2 1dpa',
    "VEPFIT - S316-corroded-24h-1 v2.plo": 'C-1',
    "VEPFIT - S316-corroded-24h-2 v2.plo": 'C-2',
    "VEPFIT - S316-irrad-1dpa-corroded-24h - 1, fix L+ to value from Corr 1 and 2.plo": "IC 1dpa 24 h",
    "VEPFIT - S316-irrad-4dpa-backside-1.plo": "BsA-1 10 h, 1",
    "VEPFIT - S316-irrad-4dpa-backside-scratch-1.plo": "BsA-2 10 h, 2",
    "VEPFIT - S316 - irrad - 4dpa - 1.plo": "4dpa 10 h"
}

# 1. We completely clear the dictionary to erase the old memory
vepfit_data = {}

for filename, short_name in file_mapping.items():
    full_path = os.path.join(data_folder, filename)
    
    if os.path.exists(full_path):
        try:
            raw_data = np.genfromtxt(full_path, delimiter=',')
            
            # 2. Extracting with the perfect column indices
            vepfit_data[short_name] = {
                'Energy': raw_data[:, 0], # Column 1
                'S_fit':  raw_data[:, 1], # Column 2
                'S':      raw_data[:, 2], # Column 3 (Real S)
                'W_fit':  raw_data[:, 3], # Column 4
                'W':      raw_data[:, 4], # Column 5 (Real W)
            }
        except Exception as e:
            print(f"Error processing {short_name}: {e}")

# 3. Let's print the real W array to prove it worked!
print("If this worked, these numbers should be around 0.015:")
print(vepfit_data["Pos1 1dpa"]["W"][:5]) # Prints just the first 5 W values
# Out:
# If this worked, these numbers should be around 0.015:
# [0.0155 0.0163 0.0166 0.0177 0.0197]

# %%
# Polished/Washed Steels

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316NA_1, s_316NA_1, yerr=s_error_316NA_1, fmt='o', label='316NA_1', capsize=5, linestyle='-', color="#7700FF", ecolor="black")
plt.errorbar(energy_316NA_2, s_316NA_2, yerr=s_error_316NA_2, fmt='s', label='316NA_2', capsize=5, linestyle='-', color="#00FFEF", ecolor="black")
plt.errorbar(energy_316NA_3, s_316NA_3, yerr=s_error_316NA_3, fmt='^', label='316NA_3', capsize=5, linestyle='-', color="#FF0000", ecolor="black")
plt.errorbar(energy_316empty, s_316empty, yerr=s_error_316empty, fmt='d', label='316empty', capsize=5, linestyle='-', color="#000000", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["S_fit"], color="#7700FF", alpha=0.6, label="P-1")
plt.plot(vepfit_data["P-2"]["Energy"], vepfit_data["P-2"]["S_fit"], color="#00FFEF", alpha=0.6, label="P-2")
plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Polished Non-Annealed 316L')
plt.legend()
plt.grid(False)
plt.show()

# %%
# Annealed Steels

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='h', label='316AA_1', capsize=5, linestyle='-', color="darkred", ecolor="black")
plt.errorbar(energy_316AA_2, s_316AA_2, yerr=s_error_316AA_2, fmt='s', label='316AA_2', capsize=5, linestyle='-', color="red", ecolor="black")
plt.errorbar(energy_316AA_3, s_316AA_3, yerr=s_error_316AA_3, fmt='d', label='316AA_3', capsize=5, linestyle='-', color="purple", ecolor="black")
plt.errorbar

plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Annealed 316L')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.grid(True)
plt.show()

# %%
# Backside Annealed Steels

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316_4dpa_backside_1, s_316_4dpa_backside_1, yerr=s_error_316_4dpa_backside_1, fmt='o', label='Backside 316 4dpa 1', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316_4dpa_backside_2, s_316_4dpa_backside_2, yerr=s_error_316_4dpa_backside_2, fmt='^', label='Backside 316 4dpa 2', capsize=5, linestyle='-', color="green", ecolor="black")

plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Annealed 316L')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.grid(True)
plt.show()

# %%
# Backside Annealed Steels

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='h', label='316AA_1', capsize=5, linestyle='-', color="#303D3B", ecolor="black")
plt.errorbar(energy_316AA_2, s_316AA_2, yerr=s_error_316AA_2, fmt='s', label='316AA_2', capsize=5, linestyle='-', color="#006954", ecolor="black")
plt.errorbar(energy_316AA_3, s_316AA_3, yerr=s_error_316AA_3, fmt='d', label='316AA_3', capsize=5, linestyle='-', color="#01FFCB", ecolor="black")

plt.errorbar(energy_316VA_1, s_316VA_1, yerr=s_error_316VA_1, fmt='v', label='Annealing 10h (vac)', capsize=5, linestyle='-', color="#FF00C6", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2, yerr=s_error_316VA_2, fmt='^', label='Annealing 2.5h (vac)', capsize=5, linestyle='-', color="#9CFF00", ecolor="black")

plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Annealed 316L in Argon and Vacuum')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.grid(False)

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(energy_316VA_1, s_316VA_1, yerr=s_error_316VA_1, fmt='v', label='Annealing 10h (vac)', capsize=5, linestyle='-', color="#FF00C6", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2, yerr=s_error_316VA_2, fmt='^', label='Annealing 2.5h (vac)', capsize=5, linestyle='-', color="#9CFF00", ecolor="black")
#plt.errorbar(energy_316_4dpa_backside_1, s_316_4dpa_backside_1, yerr=s_error_316_4dpa_backside_1, fmt='h', label='Backside 4dpa 1', capsize=5, linestyle='-', color="#BDE677", ecolor="black")
plt.errorbar(energy_316_4dpa_backside_2, s_316_4dpa_backside_2, yerr=s_error_316_4dpa_backside_2, fmt='h', label='4dpa backside', capsize=5, linestyle='-', color="#46572A", ecolor="black")


plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Vacuum Annealed 316L')
plt.grid(False)
plt.legend()
plt.show()

# %%
# Irradiated Steels (Helium Implantation)


plt.figure(figsize=(10, 6))
plt.errorbar(energy_316HI_1dpa, s_316HI_1dpa, yerr=s_error_316HI_1dpa, fmt='h', label='316HI_1dpa', capsize=5, linestyle='-', color="#678040", ecolor="black")
plt.errorbar(energy_316HI_1dpa_2, s_316HI_1dpa_2, yerr=s_error_316HI_1dpa_2, fmt='s', label='316HI_1dpa_2', capsize=5, linestyle='-', color="#9DFF00", ecolor="black")
plt.errorbar(energy_316HI_1dpa_pos1, s_316HI_1dpa_pos1, yerr=s_error_316HI_1dpa_pos1, fmt='d', label='316HI_1dpa_pos1', capsize=5, linestyle='-', color="#004AFF", ecolor="black")
plt.errorbar(energy_316HI_1dpa_pos2, s_316HI_1dpa_pos2, yerr=s_error_316HI_1dpa_pos2, fmt='o', label='316HI_1dpa_pos2', capsize=5, linestyle='-', color="#FF2E00", ecolor="black")
plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS 1dpa He 316L')
plt.legend()
plt.grid(False)
plt.show()

# %%
# Irradiated Steels (Helium Implantation)


plt.figure(figsize=(10, 6))
plt.errorbar(energy_316HI_4dpa, s_316HI_4dpa, yerr=s_error_316HI_4dpa, fmt='h', label='316HI_4dpa', capsize=5, linestyle='-', color="purple", ecolor="black")
plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS 4dpa He 316L')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Selected S-parameter for full analysis

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316NA_1, s_316NA_1, yerr=s_error_316NA_1, fmt='d', label='Pristine', capsize=2, linestyle='-', color="#7700FF", ecolor="black")
plt.errorbar(energy_316VA_1, s_316VA_1, yerr=s_error_316VA_1, fmt='v', label='Annealing 10h (vac)', capsize=2, linestyle='-', color="#FF00C6", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2, yerr=s_error_316VA_2, fmt='^', label='Annealing 2.5h (vac)', capsize=2, linestyle='-', color="#9CFF00", ecolor="black")
plt.errorbar(energy_316HI_4dpa, s_316HI_4dpa, yerr=s_error_316HI_4dpa, fmt='p', label='4dpa', capsize=2, linestyle='-', color="#804071", ecolor="black")
plt.errorbar(energy_316HI_1dpa_pos1, s_316HI_1dpa_pos1, yerr=s_error_316HI_1dpa_pos1, fmt='h', label='1dpa', capsize=2, linestyle='-', color="#678040", ecolor="black")
plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('316L S-parameter Comparison')
plt.legend()
plt.grid(False)
plt.show()

# %%
# Selected S-parameter for full analysis

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316NA_1, s_316NA_1, yerr=s_error_316NA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="grey", ecolor="grey")
plt.errorbar(energy_316VA_1, s_316VA_1, yerr=s_error_316VA_1, fmt='s', label='Vacuum annealing 10h', capsize=5, linestyle='-', color="grey", ecolor="grey")
plt.errorbar(energy_316VA_2, s_316VA_2, yerr=s_error_316VA_2, fmt='^', label='Vacuum annealing 2.5h', capsize=5, linestyle='-', color="grey", ecolor="grey")
plt.errorbar(energy_316HI_1dpa_pos1, s_316HI_1dpa_pos1, yerr=s_error_316HI_1dpa_pos1, fmt='h', label='1dpa, annealed 2.5h ', capsize=5, linestyle='-', color="green", ecolor="black")
plt.errorbar(energy_316HI_4dpa, s_316HI_4dpa, yerr=s_error_316HI_4dpa, fmt='h', label='4dpa, annealed 10h ', capsize=5, linestyle='-', color="purple", ecolor="black")
plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('316 S-parameter of Implanted Samples')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Backside Annealed Steels

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316_4dpa_backside_2, s_316_4dpa_backside_2, yerr=s_error_316_4dpa_backside_2, fmt='o', label='Backside 316 4dpa 1', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316corr_1, s_316corr_1, yerr=s_error_316corr_1, fmt='^', label='Corroded', capsize=5, linestyle='-', color="green", ecolor="black")
plt.errorbar(energy_316corr_1dpa, s_316corr_1dpa, yerr=s_error_316corr_1dpa, fmt='^', label='1dpa corroded', capsize=5, linestyle='-', color="yellow", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2, yerr=s_error_316VA_2, fmt='v', label='Annealing 10h (vac)', capsize=5, linestyle='-', color="#FF00C6", ecolor="black")


plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('PAS Annealed 316L')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.grid(True)
plt.show()

# %%
# Pristine, Annealed, Corroded

plt.figure(figsize=(10, 6))
plt.errorbar(energy_316NA_1, s_316NA_1, yerr=s_error_316NA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316corr_1, s_316corr_1, yerr=s_error_316corr_1, fmt='^', label='Corroded 24 h 650 C', capsize=5, linestyle='-', color="green", ecolor="black")
#plt.errorbar(energy_316corr_1dpa, s_316corr_1dpa, yerr=s_error_316corr_1dpa, fmt='^', label='1dpa corroded', capsize=5, linestyle='-', color="yellow", ecolor="black")
plt.errorbar(energy_316VA_1, s_316VA_1, yerr=s_error_316VA_1, fmt='v', label='Vac. anneal 10 h 650 C', capsize=5, linestyle='-', color="#FF00C6", ecolor="black")


plt.xlabel('Energy [keV]')
plt.ylabel('S-parameter')
plt.title('Pristine, Thermal Annealed and Corroded 316L')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()


plt.figure(figsize=(10, 6))
plt.errorbar(energy_316NA_1, w_316NA_1, yerr=w_error_316NA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316corr_1, w_316corr_1, yerr=w_error_316corr_1, fmt='^', label='Corroded 24 h 650 C', capsize=5, linestyle='-', color="green", ecolor="black")
#plt.errorbar(energy_316corr_1dpa, s_316corr_1dpa, yerr=s_error_316corr_1dpa, fmt='^', label='1dpa corroded', capsize=5, linestyle='-', color="yellow", ecolor="black")
plt.errorbar(energy_316VA_1, w_316VA_1, yerr=w_error_316VA_1, fmt='v', label='Vac. anneal 10 h 650 C', capsize=5, linestyle='-', color="#FF00C6", ecolor="black")


plt.xlabel('Energy [keV]')
plt.ylabel('W-parameter')
plt.title('Pristine, Thermal Annealed and Corroded 316L')
plt.legend()
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()

# %%
# Ref index

n = 10

# %%
#Annealed, Corroded and Implanted
print(vepfit_data["P-1"])
plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, s_316NA_1/f["S2"][n], yerr=s_error_316NA_1/f["S2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2/f["S2"][n], yerr=s_error_316VA_2/f["S2"][n], fmt='o', label='Annealed (Ref)', capsize=1, color="#0054ad", ecolor="black")
plt.errorbar(energy_316HI_1dpa_pos1, s_316HI_1dpa_pos1/f["S2"][n], yerr=s_error_316HI_1dpa_pos1/f["S2"][n], fmt='h', label='He-implanted (1dpa)', capsize=1, color="orange", ecolor="black")
plt.errorbar(energy_316corr_1dpa, s_316corr_1dpa/f["S2"][n], yerr=s_error_316corr_1dpa/f["S2"][n], fmt='^', label='Corroded He-implanted (1dpa)', capsize=1, color="brown", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["S_fit"]/f["S2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["S_fit"]/f["S2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["Pos1 1dpa"]["Energy"], vepfit_data["Pos1 1dpa"]["S_fit"]/f["S2"][n], linestyle="-",color="orange",alpha=0.6, lw=1)
plt.plot(vepfit_data["IC 1dpa 24 h"]["Energy"], vepfit_data["IC 1dpa 24 h"]["S_fit"]/f["S2"][n], linestyle="-",color="brown",alpha=0.6, lw=1)

plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title(r'Evolution of W-parameter of He-implanted 316L', fontsize=22)
plt.legend(loc='lower left', fontsize='large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()



plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, w_316NA_1/f["W2"][n], yerr=w_error_316NA_1/f["W2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316VA_2, w_316VA_2/f["W2"][n], yerr=w_error_316VA_2/f["W2"][n], fmt='o', label='Annealed (Ref)', capsize=1, color="#0054ad", ecolor="black")
plt.errorbar(energy_316HI_1dpa_pos1, w_316HI_1dpa_pos1/f["W2"][n], yerr=w_error_316HI_1dpa_pos1/f["W2"][n], fmt='h', label='He-implanted (1dpa)', capsize=1, color="orange", ecolor="black")
plt.errorbar(energy_316corr_1dpa, w_316corr_1dpa/f["W2"][n], yerr=w_error_316corr_1dpa/f["W2"][n], fmt='^', label='Corroded He-implanted (1dpa)', capsize=1, color="brown", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["W_fit"]/f["W2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["W_fit"]/f["W2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["Pos1 1dpa"]["Energy"], vepfit_data["Pos1 1dpa"]["W_fit"]/f["W2"][n], linestyle="-",color="orange",alpha=0.6, lw=1)
plt.plot(vepfit_data["IC 1dpa 24 h"]["Energy"], vepfit_data["IC 1dpa 24 h"]["W_fit"]/f["W2"][n], linestyle="-",color="brown",alpha=0.6, lw=1)

# Information
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT Pos1 1dpa, $L_{+} = 47.4 \pm 1.13$ nm"
"VEPFIT IC 1dpa 24 h, $L_{+} = 2.76 \pm 2.03$ nm"


plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('W-parameter', fontsize=20)
plt.title(r'Evolution of W-parameter of He-implanted 316L', fontsize=22)
plt.legend(loc="lower right", fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()
# Out:
# {'Energy': array([ 0.2   ,  0.6   ,  1.004 ,  1.412 ,  1.8242,  2.2404,  2.6608,
#         3.0854,  3.5143,  3.9474,  4.3849,  4.8267,  5.273 ,  5.7237,
#         6.179 ,  6.6388,  7.1031,  7.5722,  8.0459,  8.5244,  9.0076,
#         9.4957,  9.9886, 10.486 , 10.989 , 11.497 , 12.01  , 12.528 ,
#        13.052 , 13.58  , 14.114 , 14.653 , 15.198 , 15.748 , 16.303 ,
#        16.864 , 17.431 , 18.003 , 18.581 , 19.165 , 19.755 , 20.35  ,
#        20.952 , 21.559 , 22.173 , 22.792 , 23.418 , 24.05  ]), 'S_fit': array([0.58352, 0.57552, 0.57011, 0.56761, 0.56652, 0.56608, 0.56579,
#        0.56565, 0.56557, 0.56552, 0.56549, 0.56547, 0.56545, 0.56544,
#        0.56544, 0.56543, 0.56543, 0.56543, 0.56542, 0.56542, 0.56542,
#        0.56542, 0.56542, 0.56542, 0.56542, 0.56542, 0.56542, 0.56541,
#        0.56541, 0.56541, 0.56541, 0.56541, 0.56541, 0.56541, 0.56541,
#        0.56541, 0.56541, 0.56541, 0.56541, 0.56541, 0.56541, 0.56541,
# ...

# %%
#Annealed, Corroded and Implanted

plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, s_316NA_1/f["S2"][n], yerr=s_error_316NA_1/f["S2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2/f["S2"][n], yerr=s_error_316VA_2/f["S2"][n], fmt='o', label='Annealed (Ref)', capsize=1, color="#0054ad", ecolor="black")
plt.errorbar(energy_316corr_1, s_316corr_1/f["S2"][n], yerr=s_error_316corr_1/f["S2"][n], fmt='h', label='Corroded Sample 1', capsize=1, color="red", ecolor="black")
plt.errorbar(energy_316corr_2, s_316corr_2/f["S2"][n], yerr=s_error_316corr_2/f["S2"][n], fmt='h', label='Corroded Sample 2', capsize=1, color="darkred", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["S_fit"]/f["S2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["S_fit"]/f["S2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["C-1"]["Energy"], vepfit_data["C-1"]["S_fit"]/f["S2"][n], linestyle="-",color="red",alpha=0.6, lw=1)
plt.plot(vepfit_data["C-2"]["Energy"], vepfit_data["C-2"]["S_fit"]/f["S2"][n], linestyle="-",color="darkred",alpha=0.6, lw=1)

# Information about data
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT C-1, $L_{+} = 147 \pm 1.19$ nm"
"VEPFIT C-2,  $L_{+} = 164 \pm 1.18$ nm"




plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title(r'Evolution of S-parameter of corroded 316L', fontsize=22)
plt.legend(loc="lower left", fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()



plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, w_316NA_1/f["W2"][n], yerr=w_error_316NA_1/f["W2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316VA_2, w_316VA_2/f["W2"][n], yerr=w_error_316VA_2/f["W2"][n], fmt='o', label='Annealed (Ref)', capsize=1, color="#0054ad", ecolor="black")
plt.errorbar(energy_316corr_1, w_316corr_1/f["W2"][n], yerr=w_error_316corr_1/f["W2"][n], fmt='h', label='Corroded Sample 1', capsize=1, color="red", ecolor="black")
plt.errorbar(energy_316corr_2, w_316corr_2/f["W2"][n], yerr=w_error_316corr_2/f["W2"][n], fmt='h', label='Corroded Sample 2', capsize=1, color="darkred", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["W_fit"]/f["W2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["W_fit"]/f["W2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["C-1"]["Energy"], vepfit_data["C-1"]["W_fit"]/f["W2"][n], linestyle="-",color="red",alpha=0.6, lw=1)
plt.plot(vepfit_data["C-2"]["Energy"], vepfit_data["C-2"]["W_fit"]/f["W2"][n], linestyle="-",color="darkred",alpha=0.6, lw=1)


plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('W-parameter', fontsize=20)
plt.title(r'Evolution of W-parameter of corroded 316L', fontsize=22)
plt.legend(loc="lower right", fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:16: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:18: SyntaxWarning: invalid escape sequence '\p'
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:16: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:18: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\jeanv\AppData\Local\Temp\ipykernel_15628\910320752.py:15: SyntaxWarning: invalid escape sequence '\p'
#   "VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
# C:\Users\jeanv\AppData\Local\Temp\ipykernel_15628\910320752.py:16: SyntaxWarning: invalid escape sequence '\p'
#   "VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
# C:\Users\jeanv\AppData\Local\Temp\ipykernel_15628\910320752.py:17: SyntaxWarning: invalid escape sequence '\p'
#   "VEPFIT C-1, $L_{+} = 147 \pm 1.19$ nm"
# ...

# %%
#Annealed, Corroded and Implanted

plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, s_316NA_1/f["S2"][n], yerr=s_error_316NA_1/f["S2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316AA_1, s_316AA_1/f["S2"][n], yerr=s_error_316AA_1/f["S2"][n], fmt='o', label='Annealed (Ar), Protocol A', capsize=1, color="skyblue", ecolor="black")
plt.errorbar(energy_316AA_2, s_316AA_2/f["S2"][n], yerr=s_error_316AA_2/f["S2"][n], fmt='h', label='Annealed (Ar), Protocol B', capsize=1, color="blue", ecolor="black")
plt.errorbar(energy_316AA_3, s_316AA_3/f["S2"][n], yerr=s_error_316AA_3/f["S2"][n], fmt='h', label='Remeasurement (Protocol A)', capsize=1, color="darkblue", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["S_fit"]/f["S2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 1"]["Energy"], vepfit_data["AA 10 h, 1"]["S_fit"]/f["S2"][n], linestyle="-",color="skyblue",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 2"]["Energy"], vepfit_data["AA 10 h, 2"]["S_fit"]/f["S2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 3"]["Energy"], vepfit_data["AA 10 h, 3"]["S_fit"]/f["S2"][n], linestyle="-",color="darkblue",alpha=0.6, lw=1)

# Samples used here:
"P-1"
"AA 10 h 1"
"AA 10 h 2"
"AA 10 h 3"
# Information on vepfit results for this plot
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT AA 10 h 2, $L_{+} = 183 \pm 6.92$ nm"
"VEPFIT AA 10 h 3, $L_{+} = 85.8 \pm 2.71$ nm"


plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title(r'Evolution of S-parameter of annealed (Ar) 316L', fontsize=22)
plt.legend(loc='lower left', fontsize='large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()



plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, w_316NA_1/f["W2"][n], yerr=w_error_316NA_1/f["W2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316AA_1, w_316AA_1/f["W2"][n], yerr=w_error_316AA_1/f["W2"][n], fmt='o', label='Annealed (Ar), Protocol A', capsize=1, color="skyblue", ecolor="black")
plt.errorbar(energy_316AA_2, w_316AA_2/f["W2"][n], yerr=w_error_316AA_2/f["W2"][n], fmt='h', label='Annealed (Ar), Protocol B', capsize=1, color="blue", ecolor="black")
plt.errorbar(energy_316AA_3, w_316AA_3/f["W2"][n], yerr=w_error_316AA_3/f["W2"][n], fmt='h', label='Remeasurement (Protocol A)', capsize=1, color="darkblue", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["W_fit"]/f["W2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 1"]["Energy"], vepfit_data["AA 10 h, 1"]["W_fit"]/f["W2"][n], linestyle="-",color="skyblue",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 2"]["Energy"], vepfit_data["AA 10 h, 2"]["W_fit"]/f["W2"][n], linestyle="-",color="blue",alpha=0.6, lw=1)
plt.plot(vepfit_data["AA 10 h, 3"]["Energy"], vepfit_data["AA 10 h, 3"]["W_fit"]/f["W2"][n], linestyle="-",color="darkblue",alpha=0.6, lw=1)

# Samples used here:
"P-1"
"AA 10 h 1"
"AA 10 h 2"
"AA 10 h 3"
# Information on vepfit results for this plot
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT AA 10 h 2, $L_{+} = 183 \pm 6.92$ nm"
"VEPFIT AA 10 h 3, $L_{+} = 85.8 \pm 2.71$ nm"



plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('W-parameter', fontsize=20)
plt.title(r'Evolution of W-parameter of annealed (Ar) 316L', fontsize=22)
plt.legend(loc='lower right', fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\p'
# <>:21: SyntaxWarning: invalid escape sequence '\p'
# <>:22: SyntaxWarning: invalid escape sequence '\p'
# <>:23: SyntaxWarning: invalid escape sequence '\p'
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:20: SyntaxWarning: invalid escape sequence '\p'
# <>:21: SyntaxWarning: invalid escape sequence '\p'
# <>:22: SyntaxWarning: invalid escape sequence '\p'
# <>:23: SyntaxWarning: invalid escape sequence '\p'
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\jeanv\AppData\Local\Temp\ipykernel_15628\2689428150.py:20: SyntaxWarning: invalid escape sequence '\p'
# ...

# %%
#Annealed, Corroded and Implanted

plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, s_316NA_1/f["S2"][n], yerr=s_error_316NA_1/f["S2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.plot([0, 25], [1, 1], linestyle="--", color="grey", alpha=0.7)  # Reference line at S/S_ref = 1
plt.errorbar(energy_316VA_1, s_316VA_1/f["S2"][n], yerr=s_error_316VA_1/f["S2"][n], fmt='o', label='Annealed (Vacuum, 10 h)', capsize=1, color="#7497bd", ecolor="black")
plt.errorbar(energy_316VA_2, s_316VA_2/f["S2"][n], yerr=s_error_316VA_2/f["S2"][n], fmt='h', label='Annealed (Vacuum, 2.5 h)', capsize=1, color="#0054ad", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["S_fit"]/f["S2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 10 h"]["Energy"], vepfit_data["VA 10 h"]["S_fit"]/f["S2"][n], linestyle="-",color="#7497bd",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["S_fit"]/f["S2"][n], linestyle="-",color="#0054ad",alpha=0.6, lw=1)

# Samples used here:
"P-1"
"VA 10 h, 1"
"VA 10 h, 2"
# Information on vepfit results for this plot
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT AA 10 h 2, $L_{+} = 183 \pm 6.92$ nm"
"VEPFIT AA 10 h 3, $L_{+} = 85.8 \pm 2.71$ nm"


plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title(r'Evolution of S-parameter of annealed (Vac) 316L', fontsize=22)
plt.legend(loc='lower left', fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()



plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316NA_1, w_316NA_1/f["W2"][n], yerr=w_error_316NA_1/f["W2"][n], fmt='^', label='As-received', capsize=1, color="green", ecolor="black")
plt.errorbar(energy_316VA_1, w_316VA_1/f["W2"][n], yerr=w_error_316VA_1/f["W2"][n], fmt='o', label='Annealed (Vacuum, 10 h)', capsize=1, color="#7497bd", ecolor="black")
plt.errorbar(energy_316VA_2, w_316VA_2/f["W2"][n], yerr=w_error_316VA_2/f["W2"][n], fmt='h', label='Annealed (Vacuum, 2.5 h)', capsize=1, color="#0054ad", ecolor="black")
plt.plot(vepfit_data["P-1"]["Energy"], vepfit_data["P-1"]["W_fit"]/f["W2"][n], linestyle="-",color="green",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 10 h"]["Energy"], vepfit_data["VA 10 h"]["W_fit"]/f["W2"][n], linestyle="-",color="#7497bd",alpha=0.6, lw=1)
plt.plot(vepfit_data["VA 2.5 h"]["Energy"], vepfit_data["VA 2.5 h"]["W_fit"]/f["W2"][n], linestyle="-",color="#0054ad",alpha=0.6, lw=1)


# Samples used here:
"P-1"
"AA 10 h 1"
"AA 10 h 2"
"AA 10 h 3"
# Information on vepfit results for this plot
"VEPFIT P-1, $L_{+} = 2.58 \pm 0.76$ nm"
"VEPFIT AA 10 h 1, $L_{+} = 141 \pm 4.07$ nm"
"VEPFIT AA 10 h 2, $L_{+} = 183 \pm 6.92$ nm"
"VEPFIT AA 10 h 3, $L_{+} = 85.8 \pm 2.71$ nm"



plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('W-parameter', fontsize=20)
plt.title(r'Evolution of W-parameter of annealed (Vac) 316L', fontsize=22)
plt.legend(loc='lower right', fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\p'
# <>:19: SyntaxWarning: invalid escape sequence '\p'
# <>:20: SyntaxWarning: invalid escape sequence '\p'
# <>:21: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\p'
# <>:50: SyntaxWarning: invalid escape sequence '\p'
# <>:51: SyntaxWarning: invalid escape sequence '\p'
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# <>:18: SyntaxWarning: invalid escape sequence '\p'
# <>:19: SyntaxWarning: invalid escape sequence '\p'
# <>:20: SyntaxWarning: invalid escape sequence '\p'
# <>:21: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\p'
# <>:50: SyntaxWarning: invalid escape sequence '\p'
# <>:51: SyntaxWarning: invalid escape sequence '\p'
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\jeanv\AppData\Local\Temp\ipykernel_15628\2585968956.py:18: SyntaxWarning: invalid escape sequence '\p'
# ...

# %%
plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
#plt.errorbar(w_316corr_1, s_316corr_1, xerr=w_error_316corr_1, yerr=s_error_316corr_1, fmt='^', label='C-1', capsize=1, color="red", ecolor="black")
plt.errorbar(w_316corr_2,s_316corr_2, xerr=w_error_316corr_2, yerr=s_error_316corr_2, fmt='o', label='C-2', capsize=1, color="darkred", ecolor="black")
#plt.errorbar(w_316AA_1, s_316AA_1, xerr=w_error_316AA_1, yerr=s_error_316AA_1, fmt='^', label='AA-1', capsize=1, color="blue", ecolor="black")
#plt.errorbar(w_316corr_1dpa, s_316corr_1dpa, xerr=w_error_316corr_1dpa, yerr=s_error_316corr_1dpa, fmt='^', label='IC (1 dpa)', capsize=1, color="cyan", ecolor="black")



plt.xlabel('W-parameter', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title('Corrosion Sample (S-W) Mapping', fontsize=22)
plt.legend()
plt.show()

# %%
#Annealed, Corroded and Implanted
plt.figure(figsize=(10, 6))
#plt.errorbar(energy_316AA_1, s_316AA_1, yerr=s_error_316AA_1, fmt='o', label='Pristine', capsize=5, linestyle='-', color="blue", ecolor="black")
plt.errorbar(energy_316HI_4dpa, s_316HI_4dpa/f["S2"][n], yerr=s_error_316HI_4dpa/f["S2"][n], fmt='^', label='4 dpa', capsize=1, color="purple", ecolor="black")
plt.plot(vepfit_data["4dpa 10 h"]["Energy"], vepfit_data["4dpa 10 h"]["S_fit"]/f["S2"][n], linestyle="-",color="purple",alpha=0.6, lw=1)


plt.xlabel('Energy [keV]', fontsize=20)
plt.ylabel('S-parameter', fontsize=20)
plt.title(r'He 4dpa 316L', fontsize=22)
plt.legend(loc='upper left', fontsize='x-large')
plt.xlim(0, 25)  # Adjust x-axis limits as needed
plt.show()

# %% [markdown]
# # S-W plot
#
# Comparisons:
# 1) Pristine and Annealing
# 2) Annealing and Corrosion
# 3) Annealing and He implantation
# 4) Annealing and Corrosion
# 5) Annealing, Implantation and Corrosion

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

class PASAnalyzer:
    def __init__(self, data_dict, rename_map, surf_e, bulk_e):
        self.data = data_dict
        self.rename_map = rename_map
        self.surf_e = surf_e
        self.bulk_e = bulk_e
        self.ref_s = 1.0
        self.ref_w = 1.0
        
        # Color logic based on your SHORT labels
        self.condition_colors = {
            'P-1': '#2ca02c',      # Pristine (Green)
            'P-2': '#2ca97c',      # Pristine (Green)
            'AA': '#1f77b4',      # Air Annealed (Blue)
            'VA': '#7497bd',      # Vacuum Annealed (Purple)
            '1dpa': '#ff7f0e',      # Irradiated (Orange)
            'Pos1': '#ffbb78',  # Irradiated Pos1 (Light Orange)
            'Pos2': '#ff9866',  # Irradiated Pos2 (Lighter Orange)
            'BsA-1': "#781fb4",      # Backside Annealed (Dark Purple)
            'BsA-2': "#ad5ee1",      # Backside Annealed (Light Purple)
            '4dpa': "#E9FF6D",     # 4dpa (Medium Purple)
            'C-1': '#d62728',      # Corroded (Red)
            'C-2': "#ff2a26",     # Corroded 2 (Light Red)
            'IC': '#8c564b',      # Irradiated + Corroded (Brown)
        }

    def set_reference(self, sample_key):
        df = self.data[sample_key]
        idx = (df['Energy'] - self.bulk_e).abs().idxmin()
        self.ref_s = df.iloc[idx]['S']
        self.ref_w = df.iloc[idx]['W']
        print(f"Reference set to: {self.rename_map.get(sample_key)}")

    def _get_color(self, label):
        for key, color in self.condition_colors.items():
            if label.startswith(key):
                return color
        return '#7f7f7f' 

    def plot_comparison(self, keys_to_plot, title="S-W Parameter Map"):
        plt.figure(figsize=(10, 9))
        
        for key in keys_to_plot:
            if key not in self.data: continue
            
            label = self.rename_map.get(key, key)
            df = self.data[key]
            color = self._get_color(label)
            
            # Indices for Surface and Bulk
            idx_s = (df['Energy'] - self.surf_e).abs().idxmin()
            idx_b = (df['Energy'] - self.bulk_e).abs().idxmin()
            
            # 1. Extract Values and Errors
            s_raw = np.array([df.iloc[idx_s]['S'], df.iloc[idx_b]['S']])
            w_raw = np.array([df.iloc[idx_s]['W'], df.iloc[idx_b]['W']])
            s_err_raw = np.array([df.iloc[idx_s]['S_error'], df.iloc[idx_b]['S_error']])
            w_err_raw = np.array([df.iloc[idx_s]['W_error'], df.iloc[idx_b]['W_error']])

            # 2. Normalize Everything
            s_vec = s_raw / self.ref_s
            w_vec = w_raw / self.ref_w
            s_err = s_err_raw / self.ref_s
            w_err = w_err_raw / self.ref_w

            s_vec = s_raw 
            w_vec = w_raw 
            s_err = s_err_raw 
            w_err = w_err_raw
            
            # 3. Plot with Error Bars
            # Plot Bulk (Circle) - Index 1
            plt.errorbar(w_vec[1], s_vec[1], xerr=w_err[1], yerr=s_err[1], 
                            fmt='o', color=color, ms=10, mec='k', capsize=3, label=f"{label} bulk")
                
                # Plot Surface (Diamond) - Index 0
            plt.errorbar(w_vec[0], s_vec[0], xerr=w_err[0], yerr=s_err[0], 
                            fmt='D', color=color, ms=8, alpha=0.6, mec='k', capsize=3, label=f"{label} surface")
                
                # Draw the connecting line
            plt.plot(w_vec, s_vec, color=color, lw=1.5, alpha=0.3)


        # Reference Lines at (1,1)
        plt.axhline(1, color='k', lw=0.5, ls='--')
        plt.axvline(1, color='k', lw=0.5, ls='--')
        
        plt.xlabel("W", fontsize=12)
        plt.ylabel("S", fontsize=12)
        plt.xlim(0.011,0.040)
        plt.ylim(0.49,0.60)
        plt.title(title, fontsize=14)
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Samples")
        plt.grid(True, ls=':', alpha=0.4)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 1. Your Mapping Dictionary
name_mapping = {
    'Jean Victor - S316-3AA - 1': 'AA 10 h (Re', 
    "Jean Victor - S316-3AA - 2": 'AA 10 h, 2', 
    "Jean Victor - S316-3VA - 1": 'VA 10 h', 
    "Jean Victor - S316-4VA - 1": 'VA 2.5 h', 
    "Jean Victor - S316-annealed 650C 10h - 1": 'AA 10 h, 3',
    "Jean Victor - S316 - as-received polished": 'P-1', 
    "Jean Victor - S316 steel non-ann + polished + washed": 'P-2',
    "Jean Victor - S316-irrad-1dpa - 2": '1dpa, 2', 
    "Jean Victor - S316-irrad-1dpa - pos1 - 1": 'Pos1 1dpa', 
    "Jean Victor - S316-irrad-1dpa - pos2 - 1": 'Pos2 1dpa',
    "Jean Victor - S316-corroded-24h - 1": 'C-1 24 h',
    "Jean Victor - S316-corroded-24h - 2": 'C-2 24 h',
    "Jean Victor - S316-irrad-1dpa-corroded-24h - 1": "IC 1dpa 24 h",
    "Jean Victor - S316-irrad-4dpa-backside-1": "BsA-1 10 h, 1",
    "Jean Victor - S316-irrad-4dpa-backside-scratch-1": "BsA-2 10 h, 2",
    "Jean Victor - S316-irrad-4dpa-1": "4dpa 10 h"
}

# 2. Setup Analyzer
surf_e = 1
bulk_e = 23.5
analyzer = PASAnalyzer(all_data, name_mapping, surf_e=surf_e, bulk_e=bulk_e)

# 3. Set Reference (using the long key)
analyzer.set_reference('Jean Victor - S316-3AA - 1')


# Define your simple titles
analyzer.rename_map = {
    'Jean Victor - S316-3AA - 1': 'AA 10 h 1', 
    "Jean Victor - S316-3AA - 2": 'AA 10 h, 2', 
    "Jean Victor - S316-3VA - 1": 'VA 10 h', 
    "Jean Victor - S316-4VA - 1": 'VA 2.5 h', 
    "Jean Victor - S316-annealed 650C 10h - 1": 'AA 10 h, 3',
    "Jean Victor - S316 - as-received polished": 'P-1', 
    "Jean Victor - S316 steel non-ann + polished + washed": 'P-2',
    "Jean Victor - S316-irrad-1dpa - 2": '1dpa, 2', 
    "Jean Victor - S316-irrad-1dpa - pos1 - 1": 'Pos1 1dpa', 
    "Jean Victor - S316-irrad-1dpa - pos2 - 1": 'Pos2 1dpa',
    "Jean Victor - S316-corroded-24h - 1": 'C-1 24 h',
    "Jean Victor - S316-corroded-24h - 2": 'C-2 24 h',
    "Jean Victor - S316-irrad-1dpa-corroded-24h - 1": "IC 1dpa 24 h",
    "Jean Victor - S316-irrad-4dpa-backside-1": "BsA-1 10 h",
    "Jean Victor - S316-irrad-4dpa-backside-scratch-1": "BsA-2 10 h",
    "Jean Victor - S316-irrad-4dpa-1": "4dpa 10 h"
}

# Set reference using the long key
analyzer.set_reference('Jean Victor - S316-3AA - 1')

# # Comparison 1: Annealed Samples
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-3AA - 2", 
#                           "Jean Victor - S316-3VA - 1", 
#                           "Jean Victor - S316-4VA - 1", 
#                           "Jean Victor - S316-annealed 650C 10h - 1"], 
#                          r"Normalized S-W Map of Annealed Samples for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# # Comparison 2: Selected Annealed and Pristine
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-3AA - 2", 
#                           "Jean Victor - S316-3VA - 1", 
#                           "Jean Victor - S316-4VA - 1", 
#                           "Jean Victor - S316 - as-received polished", 
#                           "Jean Victor - S316 steel non-ann + polished + washed"], 
#                          r"Normalized S-W Map of Pristine vs Annealed for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")

# # Comparison 3: Annealed and Corroded
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-3AA - 2", 
#                           "Jean Victor - S316-3VA - 1", 
#                           "Jean Victor - S316-4VA - 1", 
#                           "Jean Victor - S316-corroded-24h - 1"], 
#                          r"Normalized S-W Map of Annealed vs Corroded for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# # Comparison 4: Pristine and Corroded
# analyzer.plot_comparison(["Jean Victor - S316-corroded-24h - 1", 
#                           "Jean Victor - S316 - as-received polished", 
#                           "Jean Victor - S316 steel non-ann + polished + washed"], 
#                          r"Normalized S-W Map of Pristine vs Corroded for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# # Comparison 5: Annealed and Implanted
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-3AA - 2", 
#                           "Jean Victor - S316-3VA - 1", 
#                           "Jean Victor - S316-4VA - 1", 
#                           "Jean Victor - S316-irrad-1dpa - 2", 
#                           "Jean Victor - S316-irrad-1dpa - pos1 - 1", 
#                           "Jean Victor - S316-irrad-1dpa - pos2 - 1"], 
#                          r"Normalized S-W Map of Annealed vs Corroded for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# # Comparison 5: Annealed and Implanted and Corroded
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-3AA - 2", 
#                           "Jean Victor - S316-3VA - 1", 
#                           "Jean Victor - S316-4VA - 1", 
#                           "Jean Victor - S316-irrad-1dpa - 2", 
#                           "Jean Victor - S316-irrad-1dpa - pos1 - 1", 
#                           "Jean Victor - S316-irrad-1dpa - pos2 - 1", 
#                           "Jean Victor - S316-corroded-24h - 1"], 
#                          r"Normalized S-W Map of Annealed vs Corroded for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# # Comparison 5: Implanted, then corroded and Corroded
# analyzer.plot_comparison(['Jean Victor - S316-3AA - 1', 
#                           "Jean Victor - S316-irrad-1dpa - 2", 
#                           "Jean Victor - S316-irrad-1dpa - pos1 - 1", 
#                           "Jean Victor - S316-irrad-1dpa - pos2 - 1", 
#                           "Jean Victor - S316-corroded-24h - 1", 
#                           "Jean Victor - S316-irrad-1dpa-corroded-24h - 1"], 
#                          r"Normalized S-W Map of Annealed vs Corroded for $E_{surf} = 3$keV and $E_{bulk} = 22$keV")


# Comparison 6: Clusterfuck
analyzer.plot_comparison(["Jean Victor - S316 - as-received polished", 
                          "Jean Victor - S316 steel non-ann + polished + washed",
                          'Jean Victor - S316-3AA - 1', 
                          "Jean Victor - S316-3AA - 2", 
                          "Jean Victor - S316-3VA - 1", 
                          "Jean Victor - S316-4VA - 1", 
                          "Jean Victor - S316-irrad-1dpa - 2", 
                          "Jean Victor - S316-irrad-1dpa - pos1 - 1", 
                          "Jean Victor - S316-irrad-1dpa - pos2 - 1", 
                          "Jean Victor - S316-corroded-24h - 1", 
                          "Jean Victor - S316-corroded-24h - 2",
                          "Jean Victor - S316-irrad-1dpa-corroded-24h - 1", 
                          "Jean Victor - S316-irrad-4dpa-backside-1",
                          "Jean Victor - S316-irrad-4dpa-backside-scratch-1",
                          "Jean Victor - S316-irrad-4dpa-1"
                          ], 
                         f"Normalized S-W Map for Es = {surf_e} keV and Eb = {bulk_e}keV")
# Out:
# Reference set to: AA 10 h (Re
# Reference set to: AA 10 h 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the data
path = r"C:\Users\jeanv\OneDrive - Delft University of Technology\Uitwisseling - TUDelft\Courses\MEP\Experiments\PALS\Results - VEPFIT.csv"

f = pd.read_csv(
    path,
    sep=',', 
    skiprows=1, 
    header=None, 
    names=['Acronym','Sample name if you guess','Ssurf therm','Stherm_err','Sepi','err','Wsurf therm','Wtherm_err','Wepi','Wepi_err','D1','D1_err','S1','S1_err','W1','W1_err','L1+','L1_err','S2','S2_err','W2','W2_err','L2','L2_err', 'ChisqS', 'ChisqW']
)

# 2. Use a Dictionary to map your specific acronyms to your desired colors.
# This acts as both your "criteria" filter AND your color assignment!
sample_colors = {
#    'P-1': '#2ca02c',        # Pristine (Green)
    'P-2': '#2ca97c',        # Pristine (Green)
    'AA 10 h 1': '#1f77b4',  # Air Annealed (Blue)
#    'AA 10 h 2': '#1f77b4',  # Air Annealed (Blue)
#    'AA 10 h 3': '#1f77b4',  # Air Annealed (Blue)
    'VA 10 h': '#7497bd',    # Vacuum Annealed (Purple)
    'VA 2.5 h': '#7497bd',    # Vacuum Annealed (Purple)
    '1dpa 1': '#ff7f0e',     # Irradiated (Orange)
#    'Pos1 1dpa': '#ffbb78',  # Irradiated Pos1 (Light Orange)
#    'Pos2 1dpa': '#ff9866',  # Irradiated Pos2 (Lighter Orange)
#    'VA 4dpa-b 1': '#781fb4',# Backside Annealed (Dark Purple)
#    'VA 4dpa-b 2': '#ad5ee1',# Backside Annealed (Light Purple)
#    '4dpa 1': '#E9FF6D',     # 4dpa
#    'C-1': '#d62728',        # Corroded (Red)
    'C-1*': "#ff5555",        # Corroded (Red)
#    'C-2': '#ff2a26',        # Corroded 2 (Light Red)
    'C-2*': "#ff8787",        # Corroded 2 (Light Red)
#    '1dpa C': '#8c564b',      # Irradiated + Corroded (Brown)
    '1dpa C*': '#c27c6b'      # Irradiated + Corroded (Brown)
}

plt.figure(figsize=(10, 10.5))

# 3. Iterate through the dataframe cleanly using iterrows()
for index, row in f.iterrows():
    acronym = row['Acronym']
    
    # Check if the acronym is in our dictionary (this replaces your criteria check)
    if acronym in sample_colors:
        color = sample_colors[acronym]
        
        # Plot Bulk (Circle)
        plt.errorbar(row["W2"], row["S2"], xerr=row["W2_err"], yerr=row["S2_err"], 
                     fmt='o', color=color, ms=10, mec='k', capsize=3, label=f"{acronym} bulk")
        
        # Plot Surface (Diamond)
        plt.errorbar(row["Wsurf therm"], row["Ssurf therm"], xerr=row["Wtherm_err"], yerr=row["Stherm_err"], 
                     fmt='D', color=color, ms=8, alpha=0.6, mec='k', capsize=3, label=f"{acronym} surface")
        
        # Draw the connecting line [x1, x2], [y1, y2]
        plt.plot([row["Wsurf therm"], row["W2"]], 
                 [row["Ssurf therm"], row["S2"]], 
                 color=color, lw=1.5, alpha=0.3)

# 4. Formatting the Plot
plt.xlabel("W-parameter", fontsize=20)
plt.ylabel("S-parameter", fontsize=20)

# Adjusting limits so you can actually see the surface states (which often have much higher S/W values)
# You might need to tweak these limits based on your actual surface values!
# plt.xlim(0.005, 0.040) 
# plt.ylim(0.48, 0.62)

plt.title("VEPFIT (S,W) Mapping", fontsize=22)

# Organize the legend so it doesn't fall off the screen
plt.legend(loc='lower left', ncol=1, fontsize='large')
plt.grid(True, ls=':', alpha=0.4)
plt.tight_layout()

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

class PASAnalyzer:
    def __init__(self, data_dict, rename_map, surf_e, bulk_e, surf_e_min, surf_e_max, bulk_e_min, bulk_e_max):
        self.data = data_dict
        self.rename_map = rename_map
        self.surf_e = surf_e
        self.bulk_e = bulk_e
        self.surf_e_min = surf_e_min
        self.surf_e_max = surf_e_max
        self.bulk_e_min = bulk_e_min
        self.bulk_e_max = bulk_e_max
        self.ref_s = 1.0
        self.ref_w = 1.0
        
        # Color logic based on your SHORT labels
        self.condition_colors = {
            'P-1': '#2ca02c',      # Pristine (Green)
            'P-2': '#2ca97c',      # Pristine (Green)
            'AA': '#1f77b4',      # Air Annealed (Blue)
            'VA': '#7497bd',      # Vacuum Annealed (Purple)
            '1dpa': '#ff7f0e',      # Irradiated (Orange)
            'Pos1': '#ffbb78',  # Irradiated Pos1 (Light Orange)
            'Pos2': '#ff9866',  # Irradiated Pos2 (Lighter Orange)
            'BsA-1': "#781fb4",      # Backside Annealed (Dark Purple)
            'BsA-2': "#ad5ee1",      # Backside Annealed (Light Purple)
            '4dpa': "#E9FF6D",     # 4dpa ()
            'C-1': '#d62728',      # Corroded (Red)
            'C-2': "#ff2a26",     # Corroded 2 (Light Red)
            'IC': '#8c564b',      # Irradiated + Corroded (Brown)
        }

    def set_reference(self, sample_key):
        df = self.data[sample_key]
        idx = (df['Energy'] - self.bulk_e).abs().idxmin()
        self.ref_s = df.iloc[idx]['S']
        self.ref_w = df.iloc[idx]['W']
        print(f"Reference set to: {self.rename_map.get(sample_key)}")

    def _get_color(self, label):
        for key, color in self.condition_colors.items():
            if label.startswith(key):
                return color
        return '#7f7f7f' 

# Change the def line to set range=None
    def plot_comparison(self, keys_to_plot, title="S-W Parameter Map", energy_range=None, areas=False):
        # If no range is provided, use the class defaults inside the function
        if energy_range is None:
            energy_range = [self.surf_e_min, self.surf_e_max, self.bulk_e_min, self.bulk_e_max]
            
        plt.figure(figsize=(10, 10.5))
        ax = plt.gca() # Get current axis for the Ellipses
        
        for key in keys_to_plot:
            if key not in self.data: continue
            
            label = self.rename_map.get(key, key)
            df = self.data[key]
            color = self._get_color(label)
            
            if areas:
                # Find indices for the ranges
                idx_s_min = (df['Energy'] - energy_range[0]).abs().idxmin()
                idx_s_max = (df['Energy'] - energy_range[1]).abs().idxmin()
                idx_b_min = (df['Energy'] - energy_range[2]).abs().idxmin()
                idx_b_max = (df['Energy'] - energy_range[3]).abs().idxmin()
              
                # Calculate means for Surface (Index 0) and Bulk (Index 1)
                surf_slice = df.iloc[idx_s_min : idx_s_max + 1]
                bulk_slice = df.iloc[idx_b_min : idx_b_max + 1]

                s_vec = np.array([surf_slice['S'].mean(), bulk_slice['S'].mean()])
                w_vec = np.array([surf_slice['W'].mean(), bulk_slice['W'].mean()])
                
                # --- NEW TOTAL UNCERTAINTY AREA LOGIC ---
                # 1. Spread of the points (Standard Deviation). Handle edge case if slice is 1 point.
                s_std_surf = surf_slice['S'].std(ddof=1) if len(surf_slice) > 1 else 0
                s_std_bulk = bulk_slice['S'].std(ddof=1) if len(bulk_slice) > 1 else 0
                w_std_surf = surf_slice['W'].std(ddof=1) if len(surf_slice) > 1 else 0
                w_std_bulk = bulk_slice['W'].std(ddof=1) if len(bulk_slice) > 1 else 0

                # 2. Average instrumental error of the points
                s_instr_surf = surf_slice['S_error'].mean()
                s_instr_bulk = bulk_slice['S_error'].mean()
                w_instr_surf = surf_slice['W_error'].mean()
                w_instr_bulk = bulk_slice['W_error'].mean()

                # 3. Combine them in quadrature (Sum of Squares)
                s_err = np.array([
                    np.sqrt(s_std_surf**2 + s_instr_surf**2),
                    np.sqrt(s_std_bulk**2 + s_instr_bulk**2)
                ])
                w_err = np.array([
                    np.sqrt(w_std_surf**2 + w_instr_surf**2),
                    np.sqrt(w_std_bulk**2 + w_instr_bulk**2)
                ])
                # ----------------------------------------
                
            else:
                # Original Point-Lookup Logic
                idx_s = (df['Energy'] - self.surf_e).abs().idxmin()
                idx_b = (df['Energy'] - self.bulk_e).abs().idxmin()
                s_vec = np.array([df.iloc[idx_s]['S'], df.iloc[idx_b]['S']])
                w_vec = np.array([df.iloc[idx_s]['W'], df.iloc[idx_b]['W']])
                s_err = np.array([df.iloc[idx_s]['S_error'], df.iloc[idx_b]['S_error']])
                w_err = np.array([df.iloc[idx_s]['W_error'], df.iloc[idx_b]['W_error']])


            # --- PLOTTING ---
            if not areas:
                plt.errorbar(w_vec[1], s_vec[1], xerr=w_err[1], yerr=s_err[1], 
                            fmt='o', color=color, ms=10, mec='k', capsize=3, label=f"{label} bulk")
                plt.errorbar(w_vec[0], s_vec[0], xerr=w_err[0], yerr=s_err[0], 
                            fmt='D', color=color, ms=8, alpha=0.6, mec='k', capsize=3, label=f"{label} surface")
                plt.plot(w_vec, s_vec, color=color, lw=1.5, alpha=0.3)

            else:
                # Plot central points
                plt.plot(w_vec[1], s_vec[1], 'o', ms=10, mec='k', color=color, label=f"{label} bulk area")
                plt.plot(w_vec[0], s_vec[0], 'D', ms=10, alpha=0.6, mec='k', color=color, label=f"{label} surface area")

                # ---> ADD THIS LINE TO CONNECT THE AVERAGE POINTS <---
                plt.plot(w_vec, s_vec, color=color, lw=1.5, alpha=0.5, linestyle='--')

                # Add Ellipses (using w_err for width and s_err for height)
                for i in [0, 1]:
                    # Width/Height of Ellipse usually represent 2*sigma for the full diameter
                    ell = Ellipse(xy=(w_vec[i], s_vec[i]), 
                                  width=w_err[i]*2, height=s_err[i]*2,
                                  angle=0, edgecolor=color, facecolor=color, 
                                  alpha=0.2, linestyle='--')
                    ax.add_patch(ell)

        # Plot Styling
        plt.xlabel("W parameter", fontsize=20)
        plt.ylabel("S parameter", fontsize=20)
        plt.xlim(0.011, 0.040)
        plt.ylim(0.49, 0.61)
        plt.title(title, fontsize=22)
        plt.legend(loc='lower left', fontsize='large')
        plt.grid(True, ls=':', alpha=0.4)
        plt.tight_layout()
        plt.show()

# %%
# Define them once at the top of your script
s_min, s_max = 1.6, 3.6
b_min, b_max = 21.0, 25.0

# Pass them into the "Initialize" step
analyzer = PASAnalyzer(all_data, name_mapping, 
                       surf_e=1.5, bulk_e=18.0,
                       surf_e_min=s_min, surf_e_max=s_max, 
                       bulk_e_min=b_min, bulk_e_max=b_max)


analyzer.plot_comparison(["Jean Victor - S316 - as-received polished", 
                          "Jean Victor - S316 steel non-ann + polished + washed",
                          'Jean Victor - S316-3AA - 1', 
                          "Jean Victor - S316-3AA - 2", 
                          "Jean Victor - S316-annealed 650C 10h - 1", 
                          "Jean Victor - S316-3VA - 1", 
                          "Jean Victor - S316-4VA - 1", 
                          "Jean Victor - S316-irrad-1dpa - 2", 
                          "Jean Victor - S316-irrad-1dpa - pos1 - 1", 
                          "Jean Victor - S316-irrad-1dpa - pos2 - 1", 
                          "Jean Victor - S316-corroded-24h - 1", 
                          "Jean Victor - S316-corroded-24h - 2",
                          "Jean Victor - S316-irrad-1dpa-corroded-24h - 1", 
                          "Jean Victor - S316-irrad-4dpa-backside-1",
                          "Jean Victor - S316-irrad-4dpa-backside-scratch-1",
                          "Jean Victor - S316-irrad-4dpa-1"
                          ], 
                         f"Averaged S-W Map for Es = {s_min} - {s_max}keV and Eb = {b_min} - {b_max}keV", areas=True)


analyzer.plot_comparison(["Jean Victor - S316 steel non-ann + polished + washed",
                          'Jean Victor - S316-3AA - 1', 
                          "Jean Victor - S316-3VA - 1", 
                          "Jean Victor - S316-4VA - 1", 
                          "Jean Victor - S316-irrad-1dpa - 2", 
                          "Jean Victor - S316-corroded-24h - 1", 
                          "Jean Victor - S316-corroded-24h - 2",
                          "Jean Victor - S316-irrad-1dpa-corroded-24h - 1", 
                          ], 
                         f"Averaged S-W Map for Es = {s_min} - {s_max}keV and Eb = {b_min} - {b_max}keV", areas=True)

# %% [markdown]
# # VEPFIT S-W Map

# %%
# Data


f
# Out:
#         Acronym                           Sample name if you guess  \
# 0           P-1                   S316L - as-received polished - 1
# 1           P-2        S316L - as-received polished and washed - 1
# 2           P-3  Jean Victor - S316 - as-received polished doub...
# 3     AA 10 h 1                      S316L - annealed 650C 10h - 1
# 4       VA 10 h                                    S316L - 3VA - 1
# 5     AA 10 h 2                                    S316L - 3AA - 1
# 6   VA 4dpa-b 1                         S316-irrad-4dpa-backside-1
# 7   VA 4dpa-b 2                 S316-irrad-4dpa-backside-scratch-1
# 8     AA 10 h 3                                    S316L - 3AA - 2
# 9        1dpa 1                            S316 - irrad - 1dpa - 2
# 10     VA 2.5 h                                    S316L - 4VA - 1
# 11    Pos1 1dpa                         S316-irrad-1dpa - pos1 - 1
# 12    Pos2 1dpa                         S316-irrad-1dpa - pos2 - 1
# ...
